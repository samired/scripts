# %%
import numpy as np
import pandas as pd

# %%
trn = pd.read_csv ('tn.csv', header=True)

# %%
trn.head(5)
# Out:
#    61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN  \
# 0  61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN
# 1  61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN
# 2  61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN
# 3  61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN
# 4  61662  ABDULLAH  AL TOUQI  A  ABDOU ISMAIL  MIDDLE EAST NORTH AFRICA  OMAN
#
#    SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS  \
# 0  SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS
# 1  SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS
# 2  SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS
# 3  SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS
# 4  SURFACE LOGGING SYSTEMS  SLS DIR WOTME OMAN  OMAN FIELD OPERATIONS
#
# ...
